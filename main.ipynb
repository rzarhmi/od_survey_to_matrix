# %%
import numpy as np
import pandas as pd
import os
from RefineODs import refine_ods

# %%
class ProcessODMatrix:
    def __init__(self, already_refined, file_name, time, state, mode, orig_column='d_orisr', dest_column='d_dessr', time_column='d_hrede', mode_column='d_mode1'):
        self.survey = pd.read_csv(file_name)
        if not already_refined:
            self.survey = refine_ods(self.survey)
        self.orig_column = orig_column
        self.dest_column = dest_column
        self.time_column = time_column
        self.mode_column = mode_column
        self.time = time
        if state == "separated":
            self.mode = mode
            self.get_matrix_for_time_mode()
        else:
            self.get_matrix_for_time()
    def make_file(self, info_dict, time, mode="all"):
        result = "$OR,D2\n* From-Time To-Time\n"
        result += str(time) + " " + str(time +1) + "\n"
        result += "* Factor\n1\n"
        
        result += "*\t{:9s} {:10s} {:10s}".format("from", "to", "num of trips")
        if mode != "all":
            result += " by " + mode +"\n"
        else: 
            result += "\n"
        for (orig, dest), number in info_dict.items():
            a = "taz_" + str(orig)
            b = "taz_" + str(dest)
            c = str(number)
            result += "\t{:10s} {:10s} {:10s}".format(a, b, c) + "\n"
        od_matrix_file_name = "OD_MATRIX_"+str(time) + "-" + str(time+1)
        if mode != "all":
            od_matrix_file_name += "_"+mode
        if not os.path.exists("OD Matrix"):
            os.makedirs("OD Matrix")
        od_matrix_file = open("OD Matrix/"+od_matrix_file_name+".od", "w+")
        n = od_matrix_file.write(result)
        od_matrix_file.close()
        
        
    def get_matrix_for_time_mode(self):
        time_column, mode_column = self.time_column, self.mode_column
        orig_column, dest_column = self.orig_column, self.dest_column
        time, mode, survey = self.time, self.mode, self.survey
        survey = survey[(survey[time_column]==time) & 
                        (survey[mode_column]==mode)] 
        survey_grouped = survey.groupby([orig_column, dest_column]).size()
        survey_dict = dict(survey_grouped)
        self.make_file(survey_dict, time, mode)
    
    def get_matrix_for_time(self):
        time_column, mode_column = self.time_column, self.mode_column
        orig_column, dest_column = self.orig_column, self.dest_column
        time, survey = self.time, self.survey
        survey = survey[(survey[time_column]==time)]
        survey_grouped = survey.groupby([orig_column, dest_column]).size()
        survey_dict = dict(survey_grouped)
        self.make_file(survey_dict, time)

# %%
"""We define some parameters here"""
TIME = 16
STATES = ["separated", "together"]
STATE = STATES[1]
MODE = "Bus"
SURVEY_FILE_NAME = "OD2013(refined).csv"

ORIG_COLUMN_NAME = 'd_orisr'
DEST_COLUMN_NAME = 'd_dessr'
TIME_COLUMN_NAME = 'd_hrede'
MODE_COLUMN_NAME = 'd_mode1'

# %%
for STATE in STATES:
    for MODE in ["Vehicle", "Bus", "Subway", "Walk", "Bike", "Train", "Motorcycle", "Taxi"]:
        for TIME in range(0, 24):
            print("WORKING ON " + STATE + " " + MODE + " " + str(TIME))
            process_OD_matrix = ProcessODMatrix(already_refined=True, file_name=SURVEY_FILE_NAME,
                                                time=TIME, state=STATE, mode=MODE, 
                                                orig_column=ORIG_COLUMN_NAME, dest_column=DEST_COLUMN_NAME, 
                                                time_column=TIME_COLUMN_NAME, mode_column=MODE_COLUMN_NAME)
            print("+"*20)
# Out:
# WORKING ON separated Vehicle 0
# ++++++++++++++++++++
# WORKING ON separated Vehicle 1
# ++++++++++++++++++++
# WORKING ON separated Vehicle 2
# ++++++++++++++++++++
# WORKING ON separated Vehicle 3
# ++++++++++++++++++++
# WORKING ON separated Vehicle 4
# ++++++++++++++++++++
# WORKING ON separated Vehicle 5
# ++++++++++++++++++++
# WORKING ON separated Vehicle 6
# ++++++++++++++++++++
# WORKING ON separated Vehicle 7
# ++++++++++++++++++++
# WORKING ON separated Vehicle 8
# ++++++++++++++++++++
# WORKING ON separated Vehicle 9
# ++++++++++++++++++++
# WORKING ON separated Vehicle 10
# ++++++++++++++++++++
# WORKING ON separated Vehicle 11
# ++++++++++++++++++++
# WORKING ON separated Vehicle 12
# ++++++++++++++++++++
# WORKING ON separated Vehicle 13
# ++++++++++++++++++++
# WORKING ON separated Vehicle 14
# ++++++++++++++++++++
# WORKING ON separated Vehicle 15
# ++++++++++++++++++++
# WORKING ON separated Vehicle 16
# ++++++++++++++++++++
# WORKING ON separated Vehicle 17
# ++++++++++++++++++++
# WORKING ON separated Vehicle 18
# ++++++++++++++++++++
# WORKING ON separated Vehicle 19
# ++++++++++++++++++++
# WORKING ON separated Vehicle 20
# ++++++++++++++++++++
# WORKING ON separated Vehicle 21
# ++++++++++++++++++++
# WORKING ON separated Vehicle 22
# ++++++++++++++++++++
# WORKING ON separated Vehicle 23
# ++++++++++++++++++++
# WORKING ON separated Bus 0
# ++++++++++++++++++++
# WORKING ON separated Bus 1
# ++++++++++++++++++++
# WORKING ON separated Bus 2
# ++++++++++++++++++++
# WORKING ON separated Bus 3
# ++++++++++++++++++++
# WORKING ON separated Bus 4
# ++++++++++++++++++++
# WORKING ON separated Bus 5
# ++++++++++++++++++++
# WORKING ON separated Bus 6
# ++++++++++++++++++++
# WORKING ON separated Bus 7
# ++++++++++++++++++++
# WORKING ON separated Bus 8
# ++++++++++++++++++++
# WORKING ON separated Bus 9
# ++++++++++++++++++++
# WORKING ON separated Bus 10
# ++++++++++++++++++++
# WORKING ON separated Bus 11
# ++++++++++++++++++++
# WORKING ON separated Bus 12
# ++++++++++++++++++++
# WORKING ON separated Bus 13
# ++++++++++++++++++++
# WORKING ON separated Bus 14
# ++++++++++++++++++++
# WORKING ON separated Bus 15
# ++++++++++++++++++++
# WORKING ON separated Bus 16
# ++++++++++++++++++++
# WORKING ON separated Bus 17
# ++++++++++++++++++++
# WORKING ON separated Bus 18
# ++++++++++++++++++++
# WORKING ON separated Bus 19
# ++++++++++++++++++++
# WORKING ON separated Bus 20
# ++++++++++++++++++++
# WORKING ON separated Bus 21
# ++++++++++++++++++++
# WORKING ON separated Bus 22
# ++++++++++++++++++++
# WORKING ON separated Bus 23
# ++++++++++++++++++++
# WORKING ON separated Subway 0
# ++++++++++++++++++++
# WORKING ON separated Subway 1
# ++++++++++++++++++++
# WORKING ON separated Subway 2
# ++++++++++++++++++++
# WORKING ON separated Subway 3
# ++++++++++++++++++++
# WORKING ON separated Subway 4
# ++++++++++++++++++++
# WORKING ON separated Subway 5
# ++++++++++++++++++++
# WORKING ON separated Subway 6
# ++++++++++++++++++++
# WORKING ON separated Subway 7
# ++++++++++++++++++++
# WORKING ON separated Subway 8
# ++++++++++++++++++++
# WORKING ON separated Subway 9
# ++++++++++++++++++++
# WORKING ON separated Subway 10
# ++++++++++++++++++++
# WORKING ON separated Subway 11
# ++++++++++++++++++++
# WORKING ON separated Subway 12
# ++++++++++++++++++++
# WORKING ON separated Subway 13
# ++++++++++++++++++++
# WORKING ON separated Subway 14
# ++++++++++++++++++++
# WORKING ON separated Subway 15
# ++++++++++++++++++++
# WORKING ON separated Subway 16
# ++++++++++++++++++++
# WORKING ON separated Subway 17
# ++++++++++++++++++++
# WORKING ON separated Subway 18
# ++++++++++++++++++++
# WORKING ON separated Subway 19
# ++++++++++++++++++++
# WORKING ON separated Subway 20
# ++++++++++++++++++++
# WORKING ON separated Subway 21
# ++++++++++++++++++++
# WORKING ON separated Subway 22
# ++++++++++++++++++++
# WORKING ON separated Subway 23
# ++++++++++++++++++++
# WORKING ON separated Walk 0
# ++++++++++++++++++++
# WORKING ON separated Walk 1
# ++++++++++++++++++++
# WORKING ON separated Walk 2
# ++++++++++++++++++++
# WORKING ON separated Walk 3
# ++++++++++++++++++++
# WORKING ON separated Walk 4
# ++++++++++++++++++++
# WORKING ON separated Walk 5
# ++++++++++++++++++++
# WORKING ON separated Walk 6
# ++++++++++++++++++++
# WORKING ON separated Walk 7
# ++++++++++++++++++++
# WORKING ON separated Walk 8
# ++++++++++++++++++++
# WORKING ON separated Walk 9
# ++++++++++++++++++++
# WORKING ON separated Walk 10
# ++++++++++++++++++++
# WORKING ON separated Walk 11
# ++++++++++++++++++++
# WORKING ON separated Walk 12
# ++++++++++++++++++++
# WORKING ON separated Walk 13
# ++++++++++++++++++++
# WORKING ON separated Walk 14
# ++++++++++++++++++++
# WORKING ON separated Walk 15
# ++++++++++++++++++++
# WORKING ON separated Walk 16
# ++++++++++++++++++++
# WORKING ON separated Walk 17
# ++++++++++++++++++++
# WORKING ON separated Walk 18
# ++++++++++++++++++++
# WORKING ON separated Walk 19
# ++++++++++++++++++++
# WORKING ON separated Walk 20
# ++++++++++++++++++++
# WORKING ON separated Walk 21
# ++++++++++++++++++++
# WORKING ON separated Walk 22
# ++++++++++++++++++++
# WORKING ON separated Walk 23
# ++++++++++++++++++++
# WORKING ON separated Bike 0
# ++++++++++++++++++++
# WORKING ON separated Bike 1
# ++++++++++++++++++++
# WORKING ON separated Bike 2
# ++++++++++++++++++++
# WORKING ON separated Bike 3
# ++++++++++++++++++++
# WORKING ON separated Bike 4
# ++++++++++++++++++++
# WORKING ON separated Bike 5
# ++++++++++++++++++++
# WORKING ON separated Bike 6
# ++++++++++++++++++++
# WORKING ON separated Bike 7
# ++++++++++++++++++++
# WORKING ON separated Bike 8
# ++++++++++++++++++++
# WORKING ON separated Bike 9
# ++++++++++++++++++++
# WORKING ON separated Bike 10
# ++++++++++++++++++++
# WORKING ON separated Bike 11
# ++++++++++++++++++++
# WORKING ON separated Bike 12
# ++++++++++++++++++++
# WORKING ON separated Bike 13
# ++++++++++++++++++++
# WORKING ON separated Bike 14
# ++++++++++++++++++++
# WORKING ON separated Bike 15
# ++++++++++++++++++++
# WORKING ON separated Bike 16
# ++++++++++++++++++++
# WORKING ON separated Bike 17
# ++++++++++++++++++++
# WORKING ON separated Bike 18
# ++++++++++++++++++++
# WORKING ON separated Bike 19
# ++++++++++++++++++++
# WORKING ON separated Bike 20
# ++++++++++++++++++++
# WORKING ON separated Bike 21
# ++++++++++++++++++++
# WORKING ON separated Bike 22
# ++++++++++++++++++++
# WORKING ON separated Bike 23
# ++++++++++++++++++++
# WORKING ON separated Train 0
# ++++++++++++++++++++
# WORKING ON separated Train 1
# ++++++++++++++++++++
# WORKING ON separated Train 2
# ++++++++++++++++++++
# WORKING ON separated Train 3
# ++++++++++++++++++++
# WORKING ON separated Train 4
# ++++++++++++++++++++
# WORKING ON separated Train 5
# ++++++++++++++++++++
# WORKING ON separated Train 6
# ++++++++++++++++++++
# WORKING ON separated Train 7
# ++++++++++++++++++++
# WORKING ON separated Train 8
# ++++++++++++++++++++
# WORKING ON separated Train 9
# ++++++++++++++++++++
# WORKING ON separated Train 10
# ++++++++++++++++++++
# WORKING ON separated Train 11
# ++++++++++++++++++++
# WORKING ON separated Train 12
# ++++++++++++++++++++
# WORKING ON separated Train 13
# ++++++++++++++++++++
# WORKING ON separated Train 14
# ++++++++++++++++++++
# WORKING ON separated Train 15
# ++++++++++++++++++++
# WORKING ON separated Train 16
# ++++++++++++++++++++
# WORKING ON separated Train 17
# ++++++++++++++++++++
# WORKING ON separated Train 18
# ++++++++++++++++++++
# WORKING ON separated Train 19
# ++++++++++++++++++++
# WORKING ON separated Train 20
# ++++++++++++++++++++
# WORKING ON separated Train 21
# ++++++++++++++++++++
# WORKING ON separated Train 22
# ++++++++++++++++++++
# WORKING ON separated Train 23
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 0
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 1
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 2
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 3
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 4
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 5
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 6
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 7
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 8
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 9
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 10
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 11
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 12
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 13
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 14
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 15
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 16
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 17
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 18
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 19
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 20
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 21
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 22
# ++++++++++++++++++++
# WORKING ON separated Motorcycle 23
# ++++++++++++++++++++
# WORKING ON separated Taxi 0
# ++++++++++++++++++++
# WORKING ON separated Taxi 1
# ++++++++++++++++++++
# WORKING ON separated Taxi 2
# ++++++++++++++++++++
# WORKING ON separated Taxi 3
# ++++++++++++++++++++
# WORKING ON separated Taxi 4
# ++++++++++++++++++++
# WORKING ON separated Taxi 5
# ++++++++++++++++++++
# WORKING ON separated Taxi 6
# ++++++++++++++++++++
# WORKING ON separated Taxi 7
# ++++++++++++++++++++
# WORKING ON separated Taxi 8
# ++++++++++++++++++++
# WORKING ON separated Taxi 9
# ++++++++++++++++++++
# WORKING ON separated Taxi 10
# ++++++++++++++++++++
# WORKING ON separated Taxi 11
# ++++++++++++++++++++
# WORKING ON separated Taxi 12
# ++++++++++++++++++++
# WORKING ON separated Taxi 13
# ++++++++++++++++++++
# WORKING ON separated Taxi 14
# ++++++++++++++++++++
# WORKING ON separated Taxi 15
# ++++++++++++++++++++
# WORKING ON separated Taxi 16
# ++++++++++++++++++++
# WORKING ON separated Taxi 17
# ++++++++++++++++++++
# WORKING ON separated Taxi 18
# ++++++++++++++++++++
# WORKING ON separated Taxi 19
# ++++++++++++++++++++
# WORKING ON separated Taxi 20
# ++++++++++++++++++++
# WORKING ON separated Taxi 21
# ++++++++++++++++++++
# WORKING ON separated Taxi 22
# ++++++++++++++++++++
# WORKING ON separated Taxi 23
# ++++++++++++++++++++
# WORKING ON together Vehicle 0
# ++++++++++++++++++++
# WORKING ON together Vehicle 1
# ++++++++++++++++++++
# WORKING ON together Vehicle 2
# ++++++++++++++++++++
# WORKING ON together Vehicle 3
# ++++++++++++++++++++
# WORKING ON together Vehicle 4
# ++++++++++++++++++++
# WORKING ON together Vehicle 5
# ++++++++++++++++++++
# WORKING ON together Vehicle 6
# ++++++++++++++++++++
# WORKING ON together Vehicle 7
# ++++++++++++++++++++
# WORKING ON together Vehicle 8
# ++++++++++++++++++++
# WORKING ON together Vehicle 9
# ++++++++++++++++++++
# WORKING ON together Vehicle 10
# ++++++++++++++++++++
# WORKING ON together Vehicle 11
# ++++++++++++++++++++
# WORKING ON together Vehicle 12
# ++++++++++++++++++++
# WORKING ON together Vehicle 13
# ++++++++++++++++++++
# WORKING ON together Vehicle 14
# ++++++++++++++++++++
# WORKING ON together Vehicle 15
# ++++++++++++++++++++
# WORKING ON together Vehicle 16
# ++++++++++++++++++++
# WORKING ON together Vehicle 17
# ++++++++++++++++++++
# WORKING ON together Vehicle 18
# ++++++++++++++++++++
# WORKING ON together Vehicle 19
# ++++++++++++++++++++
# WORKING ON together Vehicle 20
# ++++++++++++++++++++
# WORKING ON together Vehicle 21
# ++++++++++++++++++++
# WORKING ON together Vehicle 22
# ++++++++++++++++++++
# WORKING ON together Vehicle 23
# ++++++++++++++++++++
# WORKING ON together Bus 0
# ++++++++++++++++++++
# WORKING ON together Bus 1
# ++++++++++++++++++++
# WORKING ON together Bus 2
# ++++++++++++++++++++
# WORKING ON together Bus 3
# ++++++++++++++++++++
# WORKING ON together Bus 4
# ++++++++++++++++++++
# WORKING ON together Bus 5
# ++++++++++++++++++++
# WORKING ON together Bus 6
# ++++++++++++++++++++
# WORKING ON together Bus 7
# ++++++++++++++++++++
# WORKING ON together Bus 8
# ++++++++++++++++++++
# WORKING ON together Bus 9
# ++++++++++++++++++++
# WORKING ON together Bus 10
# ++++++++++++++++++++
# WORKING ON together Bus 11
# ++++++++++++++++++++
# WORKING ON together Bus 12
# ++++++++++++++++++++
# WORKING ON together Bus 13
# ++++++++++++++++++++
# WORKING ON together Bus 14
# ++++++++++++++++++++
# WORKING ON together Bus 15
# ++++++++++++++++++++
# WORKING ON together Bus 16
# ++++++++++++++++++++
# WORKING ON together Bus 17
# ++++++++++++++++++++
# WORKING ON together Bus 18
# ++++++++++++++++++++
# WORKING ON together Bus 19
# ++++++++++++++++++++
# WORKING ON together Bus 20
# ++++++++++++++++++++
# WORKING ON together Bus 21
# ++++++++++++++++++++
# WORKING ON together Bus 22
# ++++++++++++++++++++
# WORKING ON together Bus 23
# ++++++++++++++++++++
# WORKING ON together Subway 0
# ++++++++++++++++++++
# WORKING ON together Subway 1
# ++++++++++++++++++++
# WORKING ON together Subway 2
# ++++++++++++++++++++
# WORKING ON together Subway 3
# ++++++++++++++++++++
# WORKING ON together Subway 4
# ++++++++++++++++++++
# WORKING ON together Subway 5
# ++++++++++++++++++++
# WORKING ON together Subway 6
# ++++++++++++++++++++
# WORKING ON together Subway 7
# ++++++++++++++++++++
# WORKING ON together Subway 8
# ++++++++++++++++++++
# WORKING ON together Subway 9
# ++++++++++++++++++++
# WORKING ON together Subway 10
# ++++++++++++++++++++
# WORKING ON together Subway 11
# ++++++++++++++++++++
# WORKING ON together Subway 12
# ++++++++++++++++++++
# WORKING ON together Subway 13
# ++++++++++++++++++++
# WORKING ON together Subway 14
# ++++++++++++++++++++
# WORKING ON together Subway 15
# ++++++++++++++++++++
# WORKING ON together Subway 16
# ++++++++++++++++++++
# WORKING ON together Subway 17
# ++++++++++++++++++++
# WORKING ON together Subway 18
# ++++++++++++++++++++
# WORKING ON together Subway 19
# ++++++++++++++++++++
# WORKING ON together Subway 20
# ++++++++++++++++++++
# WORKING ON together Subway 21
# ++++++++++++++++++++
# WORKING ON together Subway 22
# ++++++++++++++++++++
# WORKING ON together Subway 23
# ++++++++++++++++++++
# WORKING ON together Walk 0
# ++++++++++++++++++++
# WORKING ON together Walk 1
# ++++++++++++++++++++
# WORKING ON together Walk 2
# ++++++++++++++++++++
# WORKING ON together Walk 3
# ++++++++++++++++++++
# WORKING ON together Walk 4
# ++++++++++++++++++++
# WORKING ON together Walk 5
# ++++++++++++++++++++
# WORKING ON together Walk 6
# ++++++++++++++++++++
# WORKING ON together Walk 7
# ++++++++++++++++++++
# WORKING ON together Walk 8
# ++++++++++++++++++++
# WORKING ON together Walk 9
# ++++++++++++++++++++
# WORKING ON together Walk 10
# ++++++++++++++++++++
# WORKING ON together Walk 11
# ++++++++++++++++++++
# WORKING ON together Walk 12
# ++++++++++++++++++++
# WORKING ON together Walk 13
# ++++++++++++++++++++
# WORKING ON together Walk 14
# ++++++++++++++++++++
# WORKING ON together Walk 15
# ++++++++++++++++++++
# WORKING ON together Walk 16
# ++++++++++++++++++++
# WORKING ON together Walk 17
# ++++++++++++++++++++
# WORKING ON together Walk 18
# ++++++++++++++++++++
# WORKING ON together Walk 19
# ++++++++++++++++++++
# WORKING ON together Walk 20
# ++++++++++++++++++++
# WORKING ON together Walk 21
# ++++++++++++++++++++
# WORKING ON together Walk 22
# ++++++++++++++++++++
# WORKING ON together Walk 23
# ++++++++++++++++++++
# WORKING ON together Bike 0
# ++++++++++++++++++++
# WORKING ON together Bike 1
# ++++++++++++++++++++
# WORKING ON together Bike 2
# ++++++++++++++++++++
# WORKING ON together Bike 3
# ++++++++++++++++++++
# WORKING ON together Bike 4
# ++++++++++++++++++++
# WORKING ON together Bike 5
# ++++++++++++++++++++
# WORKING ON together Bike 6
# ++++++++++++++++++++
# WORKING ON together Bike 7
# ++++++++++++++++++++
# WORKING ON together Bike 8
# ++++++++++++++++++++
# WORKING ON together Bike 9
# ++++++++++++++++++++
# WORKING ON together Bike 10
# ++++++++++++++++++++
# WORKING ON together Bike 11
# ++++++++++++++++++++
# WORKING ON together Bike 12
# ++++++++++++++++++++
# WORKING ON together Bike 13
# ++++++++++++++++++++
# WORKING ON together Bike 14
# ++++++++++++++++++++
# WORKING ON together Bike 15
# ++++++++++++++++++++
# WORKING ON together Bike 16
# ++++++++++++++++++++
# WORKING ON together Bike 17
# ++++++++++++++++++++
# WORKING ON together Bike 18
# ++++++++++++++++++++
# WORKING ON together Bike 19
# ++++++++++++++++++++
# WORKING ON together Bike 20
# ++++++++++++++++++++
# WORKING ON together Bike 21
# ++++++++++++++++++++
# WORKING ON together Bike 22
# ++++++++++++++++++++
# WORKING ON together Bike 23
# ++++++++++++++++++++
# WORKING ON together Train 0
# ++++++++++++++++++++
# WORKING ON together Train 1
# ++++++++++++++++++++
# WORKING ON together Train 2
# ++++++++++++++++++++
# WORKING ON together Train 3
# ++++++++++++++++++++
# WORKING ON together Train 4
# ++++++++++++++++++++
# WORKING ON together Train 5
# ++++++++++++++++++++
# WORKING ON together Train 6
# ++++++++++++++++++++
# WORKING ON together Train 7
# ++++++++++++++++++++
# WORKING ON together Train 8
# ++++++++++++++++++++
# WORKING ON together Train 9
# ++++++++++++++++++++
# WORKING ON together Train 10
# ++++++++++++++++++++
# WORKING ON together Train 11
# ++++++++++++++++++++
# WORKING ON together Train 12
# ++++++++++++++++++++
# WORKING ON together Train 13
# ++++++++++++++++++++
# WORKING ON together Train 14
# ++++++++++++++++++++
# WORKING ON together Train 15
# ++++++++++++++++++++
# WORKING ON together Train 16
# ++++++++++++++++++++
# WORKING ON together Train 17
# ++++++++++++++++++++
# WORKING ON together Train 18
# ++++++++++++++++++++
# WORKING ON together Train 19
# ++++++++++++++++++++
# WORKING ON together Train 20
# ++++++++++++++++++++
# WORKING ON together Train 21
# ++++++++++++++++++++
# WORKING ON together Train 22
# ++++++++++++++++++++
# WORKING ON together Train 23
# ++++++++++++++++++++
# WORKING ON together Motorcycle 0
# ++++++++++++++++++++
# WORKING ON together Motorcycle 1
# ++++++++++++++++++++
# WORKING ON together Motorcycle 2
# ++++++++++++++++++++
# WORKING ON together Motorcycle 3
# ++++++++++++++++++++
# WORKING ON together Motorcycle 4
# ++++++++++++++++++++
# WORKING ON together Motorcycle 5
# ++++++++++++++++++++
# WORKING ON together Motorcycle 6
# ++++++++++++++++++++
# WORKING ON together Motorcycle 7
# ++++++++++++++++++++
# WORKING ON together Motorcycle 8
# ++++++++++++++++++++
# WORKING ON together Motorcycle 9
# ++++++++++++++++++++
# WORKING ON together Motorcycle 10
# ++++++++++++++++++++
# WORKING ON together Motorcycle 11
# ++++++++++++++++++++
# WORKING ON together Motorcycle 12
# ++++++++++++++++++++
# WORKING ON together Motorcycle 13
# ++++++++++++++++++++
# WORKING ON together Motorcycle 14
# ++++++++++++++++++++
# WORKING ON together Motorcycle 15
# ++++++++++++++++++++
# WORKING ON together Motorcycle 16
# ++++++++++++++++++++
# WORKING ON together Motorcycle 17
# ++++++++++++++++++++
# WORKING ON together Motorcycle 18
# ++++++++++++++++++++
# WORKING ON together Motorcycle 19
# ++++++++++++++++++++
# WORKING ON together Motorcycle 20
# ++++++++++++++++++++
# WORKING ON together Motorcycle 21
# ++++++++++++++++++++
# WORKING ON together Motorcycle 22
# ++++++++++++++++++++
# WORKING ON together Motorcycle 23
# ++++++++++++++++++++
# WORKING ON together Taxi 0
# ++++++++++++++++++++
# WORKING ON together Taxi 1
# ++++++++++++++++++++
# WORKING ON together Taxi 2
# ++++++++++++++++++++
# WORKING ON together Taxi 3
# ++++++++++++++++++++
# WORKING ON together Taxi 4
# ++++++++++++++++++++
# WORKING ON together Taxi 5
# ++++++++++++++++++++
# WORKING ON together Taxi 6
# ++++++++++++++++++++
# WORKING ON together Taxi 7
# ++++++++++++++++++++
# WORKING ON together Taxi 8
# ++++++++++++++++++++
# WORKING ON together Taxi 9
# ++++++++++++++++++++
# WORKING ON together Taxi 10
# ++++++++++++++++++++
# WORKING ON together Taxi 11
# ++++++++++++++++++++
# WORKING ON together Taxi 12
# ++++++++++++++++++++
# WORKING ON together Taxi 13
# ++++++++++++++++++++
# WORKING ON together Taxi 14
# ++++++++++++++++++++
# WORKING ON together Taxi 15
# ++++++++++++++++++++
# WORKING ON together Taxi 16
# ++++++++++++++++++++
# WORKING ON together Taxi 17
# ++++++++++++++++++++
# WORKING ON together Taxi 18
# ++++++++++++++++++++
# WORKING ON together Taxi 19
# ++++++++++++++++++++
# WORKING ON together Taxi 20
# ++++++++++++++++++++
# WORKING ON together Taxi 21
# ++++++++++++++++++++
# WORKING ON together Taxi 22
# ++++++++++++++++++++
# WORKING ON together Taxi 23
# ++++++++++++++++++++
